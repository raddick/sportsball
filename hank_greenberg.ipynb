# %%
import zipfile
import numpy
import pandas
#zip_ref = zipfile.ZipFile('gl1920_39.zip', 'r')
#zip_ref.extractall('.')
#zip_ref.close()
columns = ['date','gameno','dayofweek','visitor','visitor_league']
columns += ['visitor_gameno','home','home_league','home_gameno']
columns += ['visitor_score','home_score','nOuts','day_night','completed']
columns += ['forfeit','protest','park','attendance'],'length','visitor_boxscore']
columns += ['home_boxscore','visitor_ab','visitor_h','visitor_2b','visitor_3b']
columns += ['visitor_hr','visitor_rbi','visitor_sac','visitor_sacfly','visitor_hbp']
columns += ['visitor_bb','visitor_ibb','visitor_k','visitor_sb','visitor_cs']
columns += ['visitor_gidp','visitor_ci','visitor_lob','visitor_nPitchers']
columns += ['visitor_er_ind','visitor_er_team','visitor_wp','visitor_balk']
columns += ['visitor_putout','visitor_assist','visitor_e','visitor_pb']
columns += ['visitor_dp','visitor_tp','home_ab','home_h','home_2b','home_3b']
columns += ['home_hr','home_rbi','home_sac','home_sacfly','home_hbp','home_bb']
columns += ['home_ibb','home_k','home_sb','home_cs','home_gidp','home_ci']
columns += ['home_lob','home_nPitchers','home_er_ind','home_er_team','home_wp']
columns += ['home_balk','home_putout','home_assist','home_e','home_pb']
columns += ['home_dp','home_tp','ump_home_id','ump_home_name','ump_1b_id']
columns += ['ump_1b_name','ump_2b_id','ump_2b_name','ump_3b_id','ump_3b_name']
columns += ['ump_lf_id','ump_lf_name','ump_rf_id','ump_rf_name']
columns += ['visitor_manager_id','visitor_manager_name','home_manager_id']
columns += ['winning_pitcher_id','winning_pitcher_name','losing_pitcher_id']
columns += ['losing_pitcher_name','saving_pitcher_id','saving_pitcher_name']
columns += ['gw_rbi_batter_id','gw_rbi_batter_name','visitor_starting_pitcher_id']
columns += ['visitor_starting_pitcher_name','home_starting_pitcher_id']
columns += ['home_starting_pitcher_name','visitor_batter1_id','visitor_batter1_name']
columns += ['visitor_batter1_pos','visitor_batter2_id','visitor_batter2_name']
columns += ['visitor_batter2_pos','visitor_batter3_id','visitor_batter3_name']
columns += ['visitor_batter3_pos','visitor_batter4_id','visitor_batter4_name']
columns += ['visitor_batter4_pos','visitor_batter5_id','visitor_batter5_name']
columns += ['visitor_batter5_pos','visitor_batter6_id','visitor_batter6_name']
columns += ['visitor_batter6_pos','visitor_batter7_id','visitor_batter7_name']
columns += ['visitor_batter7_pos','visitor_batter8_id','visitor_batter8_name']
columns += ['visitor_batter8_pos','visitor_batter9_id','visitor_batter9_name']
columns += ['visitor_batter9_pos']
games1920 = pandas.read_csv('GL1920.TXT')
games1920.iloc[0:2,16:28]
# Out:
#    CHI10  Unnamed: 17   145 00000010100 00000200001  36  4  1.2  0.1  1.3  \
# 0  CLE06          NaN   NaN   000000000   04001000x  32  5    3    0    0
# 1  PHI11          NaN  90.0   100000000   00001002x  32  7    0    0    1
#
#    2.1  0.2
# 0    0    0
# 1    1    0
