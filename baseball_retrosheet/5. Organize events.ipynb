# %%
import json
import numpy as np
import pandas
import time
from pprint import pprint
pandas.options.display.max_colwidth = -1
print('ok')
# Out:
# ok

# %%
for i in range(1921,2018):
    filename = '/home/idies/workspace/Temporary/raddick/baseball_scratch/events_raw_by_year/events_raw_{0:}.json'.format(i)
    with open(filename,'r') as f:
        allgames = json.load(f)
    print('{0:.0f}: loaded {1:,.0f} games... '.format(i, len(allgames)))
    
    for j in range(0, len(allgames)):
#        if ((np.mod(i,500) == 0) | (i == len(allgames)-1)):
#            print('Parsing game number {0:,.0f}: {1:}'.format(i, allgames[i]['id']))
#        if (debug > 0):
#            print('\n')
#            print('Parsing game number {0:,.0f}: {1:}'.format(i, allgames[i]['id']))

        if (allgames[j]['events'][0]['event_type'] == 'com'):
            current_comment = allgames[j]['events'][0]['comment']
            first_appearance = 0
        else:
            current_comment = ''
            first_appearance = -1
            
        for k in range(1,len(allgames[j]['events'])-1):
            if (allgames[j]['events'][k]['event_type'] == 'com'):
                if (allgames[j]['events'][k-1]['event_type'] != 'com'):
                    first_appearance = k
                if (allgames[j]['events'][k]['comment'][0] == '"'):
                    allgames[j]['events'][k]['comment'] = allgames[j]['events'][k]['comment'][1:]
                if (allgames[j]['events'][k]['comment'][len(allgames[j]['events'][k]['comment'])-1] == '"'):
                    allgames[j]['events'][k]['comment'] = allgames[j]['events'][k]['comment'][:-1]
                if (k > first_appearance):
                    current_comment += ' '
                current_comment += allgames[j]['events'][k]['comment']
                if (allgames[j]['events'][k+1]['event_type'] != 'com'):
                    allgames[j]['events'][first_appearance]['comment'] = current_comment
                    current_comment = ''
        
        lastrow = len(allgames[j]['events'])-1
        if (allgames[j]['events'][lastrow]['event_type'] == 'com'):
            if (lastrow > first_appearance):
                current_comment += ' '
            current_comment += allgames[j]['events'][lastrow]['comment']
            allgames[j]['events'][first_appearance]['comment'] = current_comment
        
        if (allgames[j]['events'][0]['event_type'] == 'com'):
            allgames[j]['info']['comment'] = allgames[j]['events'][0]['comment']
            
        for k in range(0,len(allgames[j]['events'])-1):
            if ((allgames[j]['events'][k]['event_type'] != 'com') & (allgames[j]['events'][k+1]['event_type'] == 'com')):
                allgames[j]['events'][k]['comment'] = allgames[j]['events'][k+1]['comment']
        
        counter = 0
        allgames[j]['new_events'] = list()
        
        for m in range(0, len(allgames[j]['events'])):
            if (allgames[j]['events'][m]['event_type'] != 'com'):
                allgames[j]['new_events'].append(allgames[j]['events'][m])
                allgames[j]['new_events'][counter]['new_event_in_game'] = counter + 1
                counter = counter + 1
        
        for p in range(0, len(allgames[j]['new_events'])):
            del allgames[j]['new_events'][p]['event_in_game']
            allgames[j]['new_events'][p]['event_in_game'] = allgames[j]['new_events'][p]['new_event_in_game']
            del allgames[j]['new_events'][p]['new_event_in_game']
            
        allgames[j]['events'] = allgames[j]['new_events']
        del allgames[j]['new_events']
#        for w in range(0, len(allgames[j]['events'])):
#            print(allgames[j]['events'][w]['event_in_game'])

    print('Saving file...')
    with open('/home/idies/workspace/Temporary/raddick/baseball_scratch/events_by_year/events_{0:}.json'.format(i), 'w') as f:
        json.dump(allgames, f)
print('Done')
# Out:
# 1921: loaded 983 games...
# Saving file...
# 1922: loaded 993 games...
# Saving file...
# 1923: loaded 1,007 games...
# Saving file...
# 1924: loaded 1,024 games...
# Saving file...
# 1925: loaded 1,014 games...
# Saving file...
# 1926: loaded 1,023 games...
# Saving file...
# 1927: loaded 1,053 games...
# Saving file...
# 1928: loaded 1,019 games...
# Saving file...
# 1929: loaded 951 games...
# Saving file...
# 1930: loaded 1,028 games...
# Saving file...
# 1931: loaded 1,050 games...
# Saving file...
# 1932: loaded 974 games...
# Saving file...
# 1933: loaded 1,017 games...
# Saving file...
# 1934: loaded 908 games...
# Saving file...
# 1935: loaded 887 games...
# Saving file...
# 1936: loaded 951 games...
# Saving file...
# 1937: loaded 1,031 games...
# Saving file...
# 1938: loaded 843 games...
# Saving file...
# 1939: loaded 1,155 games...
# Saving file...
# 1940: loaded 1,140 games...
# Saving file...
# 1941: loaded 1,090 games...
# Saving file...
# 1942: loaded 1,102 games...
# Saving file...
# 1943: loaded 995 games...
# Saving file...
# 1944: loaded 868 games...
# Saving file...
# 1945: loaded 966 games...
# Saving file...
# 1946: loaded 1,047 games...
# Saving file...
# 1947: loaded 1,113 games...
# Saving file...
# 1948: loaded 1,083 games...
# Saving file...
# 1949: loaded 1,095 games...
# Saving file...
# 1950: loaded 1,109 games...
# Saving file...
# 1951: loaded 1,145 games...
# Saving file...
# 1952: loaded 1,151 games...
# Saving file...
# 1953: loaded 1,189 games...
# Saving file...
# 1954: loaded 1,194 games...
# Saving file...
# 1955: loaded 1,201 games...
# Saving file...
# 1956: loaded 1,209 games...
# Saving file...
# 1957: loaded 1,226 games...
# Saving file...
# 1958: loaded 1,244 games...
# Saving file...
# 1959: loaded 1,249 games...
# Saving file...
# 1960: loaded 1,251 games...
# Saving file...
# 1961: loaded 1,447 games...
# Saving file...
# 1962: loaded 1,636 games...
# Saving file...
# 1963: loaded 1,635 games...
# Saving file...
# 1964: loaded 1,643 games...
# Saving file...
# 1965: loaded 1,632 games...
# Saving file...
# 1966: loaded 1,626 games...
# Saving file...
# 1967: loaded 1,632 games...
# Saving file...
# 1968: loaded 1,625 games...
# Saving file...
# 1969: loaded 1,969 games...
# Saving file...
# 1970: loaded 1,967 games...
# Saving file...
# 1971: loaded 1,952 games...
# Saving file...
# 1972: loaded 1,880 games...
# Saving file...
# 1973: loaded 1,964 games...
# Saving file...
# 1974: loaded 1,968 games...
# Saving file...
# 1975: loaded 1,957 games...
# Saving file...
# 1976: loaded 1,962 games...
# Saving file...
# 1977: loaded 2,128 games...
# Saving file...
# 1978: loaded 2,127 games...
# Saving file...
# 1979: loaded 2,123 games...
# Saving file...
# 1980: loaded 2,130 games...
# Saving file...
# 1981: loaded 1,419 games...
# Saving file...
# 1982: loaded 2,132 games...
# Saving file...
# 1983: loaded 2,134 games...
# Saving file...
# 1984: loaded 2,130 games...
# Saving file...
# 1985: loaded 2,128 games...
# Saving file...
# 1986: loaded 2,128 games...
# Saving file...
# 1987: loaded 2,130 games...
# Saving file...
# 1988: loaded 2,125 games...
# Saving file...
# 1989: loaded 2,131 games...
# Saving file...
# 1990: loaded 2,130 games...
# Saving file...
# 1991: loaded 2,129 games...
# Saving file...
# 1992: loaded 2,131 games...
# Saving file...
# 1993: loaded 2,296 games...
# Saving file...
# 1994: loaded 1,627 games...
# Saving file...
# 1995: loaded 2,044 games...
# Saving file...
# 1996: loaded 2,294 games...
# Saving file...
# 1997: loaded 2,293 games...
# Saving file...
# 1998: loaded 2,461 games...
# Saving file...
# 1999: loaded 2,457 games...
# Saving file...
# 2000: loaded 2,458 games...
# Saving file...
# 2001: loaded 2,458 games...
# Saving file...
# 2002: loaded 2,455 games...
# Saving file...
# 2003: loaded 2,459 games...
# Saving file...
# 2004: loaded 2,457 games...
# Saving file...
# 2005: loaded 2,460 games...
# Saving file...
# 2006: loaded 2,458 games...
# Saving file...
# 2007: loaded 2,460 games...
# Saving file...
# 2008: loaded 2,457 games...
# Saving file...
# 2009: loaded 2,459 games...
# Saving file...
# 2010: loaded 2,459 games...
# Saving file...
# 2011: loaded 2,458 games...
# Saving file...
# 2012: loaded 2,459 games...
# Saving file...
# 2013: loaded 2,460 games...
# Saving file...
# 2014: loaded 2,459 games...
# Saving file...
# 2015: loaded 2,458 games...
# Saving file...
# 2016: loaded 2,457 games...
# Saving file...
# 2017: loaded 2,459 games...
# Saving file...
# Done

# %%
pprint(allgames[0])
# Out:
# {'data': [{'player': 'gally001', 'thevalue': '3', 'type': 'er'},
#           {'player': 'fienc001', 'thevalue': '2', 'type': 'er'},
#           {'player': 'overd001', 'thevalue': '0', 'type': 'er'},
#           {'player': 'chavj001', 'thevalue': '1', 'type': 'er'},
#           {'player': 'alvaj003', 'thevalue': '0', 'type': 'er'},
#           {'player': 'norrb001', 'thevalue': '0', 'type': 'er'},
#           {'player': 'baila001', 'thevalue': '0', 'type': 'er'},
#           {'player': 'parkb001', 'thevalue': '0', 'type': 'er'}],
#  'events': [{'batter_id': 'seguj002',
#              'event': 'W',
#              'event_in_game': 1,
#              'event_type': 'play',
#              'inning': '1',
#              'pitch_count': '32',
#              'pitch_sequence': 'CBSBBB',
#              'visitor_or_home': '0'},
#             {'batter_id': 'hanim001',
#              'event': 'K',
#              'event_in_game': 2,
#              'event_type': 'play',
#              'inning': '1',
#              'pitch_count': '12',
#              'pitch_sequence': '1CB1FT',
#              'visitor_or_home': '0'},
#             {'batter_id': 'canor001',
#              'event': '8/F',
#              'event_in_game': 3,
#              'event_type': 'play',
#              'inning': '1',
#              'pitch_count': '11',
#              'pitch_sequence': 'BFX',
#              'visitor_or_home': '0'},
#             {'batter_id': 'cruzn002',
#              'event': 'SB2',
#              'event_in_game': 4,
#              'event_type': 'play',
#              'inning': '1',
#              'pitch_count': '01',
#              'pitch_sequence': 'C1>S',
#              'visitor_or_home': '0'},
#             {'batter_id': 'cruzn002',
#              'event': 'K',
#              'event_in_game': 5,
#              'event_type': 'play',
#              'inning': '1',
#              'pitch_count': '22',
#              'pitch_sequence': 'C1>S.*BBS',
#              'visitor_or_home': '0'},
#             {'batter_id': 'escoy001',
#              'event': 'S8/L+',
#              'event_in_game': 6,
#              'event_type': 'play',
#              'inning': '1',
#              'pitch_count': '20',
#              'pitch_sequence': 'BBX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'calhk001',
#              'event': 'DGR/78/F.1-3',
#              'event_in_game': 7,
#              'event_type': 'play',
#              'inning': '1',
#              'pitch_count': '21',
#              'pitch_sequence': 'BBFX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'troum001',
#              'event': '8/F/SF.3-H',
#              'event_in_game': 8,
#              'event_type': 'play',
#              'inning': '1',
#              'pitch_count': '12',
#              'pitch_sequence': 'CCBFFX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'pujoa001',
#              'event': '53/G',
#              'event_in_game': 9,
#              'event_type': 'play',
#              'inning': '1',
#              'pitch_count': '32',
#              'pitch_sequence': 'BC*BBFX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'cronc002',
#              'event': '53/G',
#              'event_in_game': 10,
#              'event_type': 'play',
#              'inning': '1',
#              'pitch_count': '12',
#              'pitch_sequence': 'CF*BX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'seagk001',
#              'event': '7/F',
#              'event_in_game': 11,
#              'event_type': 'play',
#              'inning': '2',
#              'pitch_count': '21',
#              'pitch_sequence': 'CBBX',
#              'visitor_or_home': '0'},
#             {'batter_id': 'valed001',
#              'event': '8/L',
#              'event_in_game': 12,
#              'event_type': 'play',
#              'inning': '2',
#              'pitch_count': '12',
#              'pitch_sequence': 'FBSFX',
#              'visitor_or_home': '0'},
#             {'batter_id': 'dysoj001',
#              'event': '3/G',
#              'event_in_game': 13,
#              'event_type': 'play',
#              'inning': '2',
#              'pitch_count': '11',
#              'pitch_sequence': 'SBX',
#              'visitor_or_home': '0'},
#             {'batter_id': 'maybc001',
#              'event': 'K',
#              'event_in_game': 14,
#              'event_type': 'play',
#              'inning': '2',
#              'pitch_count': '32',
#              'pitch_sequence': 'CFBBBC',
#              'visitor_or_home': '1'},
#             {'batter_id': 'simma001',
#              'event': '3/G-',
#              'event_in_game': 15,
#              'event_type': 'play',
#              'inning': '2',
#              'pitch_count': '02',
#              'pitch_sequence': 'CCX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'espid001',
#              'event': '3/G-',
#              'event_in_game': 16,
#              'event_type': 'play',
#              'inning': '2',
#              'pitch_count': '11',
#              'pitch_sequence': 'BTX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'zunim001',
#              'event': 'S7/L',
#              'event_in_game': 17,
#              'event_type': 'play',
#              'inning': '3',
#              'pitch_count': '22',
#              'pitch_sequence': 'CFBFBFFX',
#              'visitor_or_home': '0'},
#             {'batter_id': 'hereg002',
#              'event': '7/F',
#              'event_in_game': 18,
#              'event_type': 'play',
#              'inning': '3',
#              'pitch_count': '02',
#              'pitch_sequence': 'FSX',
#              'visitor_or_home': '0'},
#             {'batter_id': 'seguj002',
#              'event': 'K',
#              'event_in_game': 19,
#              'event_type': 'play',
#              'inning': '3',
#              'pitch_count': '22',
#              'pitch_sequence': 'FBBSS',
#              'visitor_or_home': '0'},
#             {'batter_id': 'hanim001',
#              'event': '7/F',
#              'event_in_game': 20,
#              'event_type': 'play',
#              'inning': '3',
#              'pitch_count': '10',
#              'pitch_sequence': '*BX',
#              'visitor_or_home': '0'},
#             {'batter_id': 'maldm001',
#              'event': 'S8/L+',
#              'event_in_game': 21,
#              'event_type': 'play',
#              'inning': '3',
#              'pitch_count': '20',
#              'pitch_sequence': 'BBX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'escoy001',
#              'event': 'S8/G.1-2',
#              'event_in_game': 22,
#              'event_type': 'play',
#              'inning': '3',
#              'pitch_count': '00',
#              'pitch_sequence': 'X',
#              'visitor_or_home': '1'},
#             {'batter_id': 'calhk001',
#              'event': 'K',
#              'event_in_game': 23,
#              'event_type': 'play',
#              'inning': '3',
#              'pitch_count': '12',
#              'pitch_sequence': 'BCFS',
#              'visitor_or_home': '1'},
#             {'batter_id': 'troum001',
#              'event': 'IW.2-3;1-2',
#              'event_in_game': 24,
#              'event_type': 'play',
#              'inning': '3',
#              'pitch_count': '30',
#              'pitch_sequence': 'BBBV',
#              'visitor_or_home': '1'},
#             {'batter_id': 'pujoa001',
#              'event': 'E5/FO/G.3-H;2-3;1-2',
#              'event_in_game': 25,
#              'event_type': 'play',
#              'inning': '3',
#              'pitch_count': '21',
#              'pitch_sequence': 'SB*BX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'cronc002',
#              'event': 'K',
#              'event_in_game': 26,
#              'event_type': 'play',
#              'inning': '3',
#              'pitch_count': '12',
#              'pitch_sequence': 'SS*BT',
#              'visitor_or_home': '1'},
#             {'batter_id': 'maybc001',
#              'event': '54(1)/FO/G',
#              'event_in_game': 27,
#              'event_type': 'play',
#              'inning': '3',
#              'pitch_count': '11',
#              'pitch_sequence': 'C*BX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'canor001',
#              'event': 'K',
#              'event_in_game': 28,
#              'event_type': 'play',
#              'inning': '4',
#              'pitch_count': '32',
#              'pitch_sequence': 'BCBBFC',
#              'visitor_or_home': '0'},
#             {'batter_id': 'cruzn002',
#              'event': '63/G',
#              'event_in_game': 29,
#              'event_type': 'play',
#              'inning': '4',
#              'pitch_count': '01',
#              'pitch_sequence': 'CX',
#              'visitor_or_home': '0'},
#             {'batter_id': 'seagk001',
#              'event': 'K',
#              'event_in_game': 30,
#              'event_type': 'play',
#              'inning': '4',
#              'pitch_count': '12',
#              'pitch_sequence': 'FCBS',
#              'visitor_or_home': '0'},
#             {'batter_id': 'simma001',
#              'event': '9/L',
#              'event_in_game': 31,
#              'event_type': 'play',
#              'inning': '4',
#              'pitch_count': '10',
#              'pitch_sequence': 'BX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'espid001',
#              'event': 'W',
#              'event_in_game': 32,
#              'event_type': 'play',
#              'inning': '4',
#              'pitch_count': '32',
#              'pitch_sequence': 'BBSBSB',
#              'visitor_or_home': '1'},
#             {'batter_id': 'maldm001',
#              'event': 'S9/G.1-3',
#              'event_in_game': 33,
#              'event_type': 'play',
#              'inning': '4',
#              'pitch_count': '31',
#              'pitch_sequence': 'SBB1B>X',
#              'visitor_or_home': '1'},
#             {'batter_id': 'escoy001',
#              'event': '4/L',
#              'event_in_game': 34,
#              'event_type': 'play',
#              'inning': '4',
#              'pitch_count': '21',
#              'pitch_sequence': '1FB*BX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'calhk001',
#              'event': 'K',
#              'event_in_game': 35,
#              'event_type': 'play',
#              'inning': '4',
#              'pitch_count': '02',
#              'pitch_sequence': 'FCS',
#              'visitor_or_home': '1'},
#             {'batter_id': 'valed001',
#              'event': '7/L+',
#              'event_in_game': 36,
#              'event_type': 'play',
#              'inning': '5',
#              'pitch_count': '20',
#              'pitch_sequence': 'BBX',
#              'visitor_or_home': '0'},
#             {'batter_id': 'dysoj001',
#              'event': '8/F',
#              'event_in_game': 37,
#              'event_type': 'play',
#              'inning': '5',
#              'pitch_count': '12',
#              'pitch_sequence': 'CBCX',
#              'visitor_or_home': '0'},
#             {'batter_id': 'zunim001',
#              'event': 'K',
#              'event_in_game': 38,
#              'event_type': 'play',
#              'inning': '5',
#              'pitch_count': '32',
#              'pitch_sequence': 'FBSBBS',
#              'visitor_or_home': '0'},
#             {'batter_id': 'troum001',
#              'event': 'S9/L',
#              'event_in_game': 39,
#              'event_type': 'play',
#              'inning': '5',
#              'pitch_count': '21',
#              'pitch_sequence': 'BFBX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'pujoa001',
#              'event': '8/F/DP.1X1(83)',
#              'event_in_game': 40,
#              'event_type': 'play',
#              'inning': '5',
#              'pitch_count': '01',
#              'pitch_sequence': '1CX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'cronc002',
#              'event': '5/P',
#              'event_in_game': 41,
#              'event_type': 'play',
#              'inning': '5',
#              'pitch_count': '20',
#              'pitch_sequence': 'BBX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'hereg002',
#              'event': '53/G',
#              'event_in_game': 42,
#              'event_type': 'play',
#              'inning': '6',
#              'pitch_count': '22',
#              'pitch_sequence': 'CFBFBFFX',
#              'visitor_or_home': '0'},
#             {'batter_id': 'seguj002',
#              'event': '9/F',
#              'event_in_game': 43,
#              'event_type': 'play',
#              'inning': '6',
#              'pitch_count': '00',
#              'pitch_sequence': 'X',
#              'visitor_or_home': '0'},
#             {'batter_id': 'hanim001',
#              'event': 'S7/L',
#              'event_in_game': 44,
#              'event_type': 'play',
#              'inning': '6',
#              'pitch_count': '01',
#              'pitch_sequence': 'CX',
#              'visitor_or_home': '0'},
#             {'batter_id': 'canor001',
#              'event': 'S7/L.1-3',
#              'event_in_game': 45,
#              'event_type': 'play',
#              'inning': '6',
#              'pitch_count': '12',
#              'pitch_sequence': 'FFBX',
#              'visitor_or_home': '0'},
#             {'batter_id': 'cruzn002',
#              'event': 'S7/G.3-H;1-3',
#              'event_in_game': 46,
#              'event_type': 'play',
#              'inning': '6',
#              'pitch_count': '00',
#              'pitch_sequence': 'X',
#              'visitor_or_home': '0'},
#             {'batter_id': 'seagk001',
#              'event': 'NP',
#              'event_in_game': 47,
#              'event_type': 'play',
#              'inning': '6',
#              'pitch_count': '00',
#              'pitch_sequence': '',
#              'visitor_or_home': '0'},
#             {'event_in_game': 48,
#              'event_type': 'sub',
#              'sub_batting_order': '0',
#              'sub_id': 'alvaj003',
#              'sub_name': '"Jose Alvarez"',
#              'sub_position': '1',
#              'sub_team': '1'},
#             {'batter_id': 'seagk001',
#              'event': 'K',
#              'event_in_game': 49,
#              'event_type': 'play',
#              'inning': '6',
#              'pitch_count': '02',
#              'pitch_sequence': '1.SFT',
#              'visitor_or_home': '0'},
#             {'batter_id': 'maybc001',
#              'event': 'HR/8/F',
#              'event_in_game': 50,
#              'event_type': 'play',
#              'inning': '6',
#              'pitch_count': '10',
#              'pitch_sequence': 'BX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'simma001',
#              'event': 'S9/L+',
#              'event_in_game': 51,
#              'event_type': 'play',
#              'inning': '6',
#              'pitch_count': '10',
#              'pitch_sequence': 'BX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'espid001',
#              'event': 'NP',
#              'event_in_game': 52,
#              'event_type': 'play',
#              'inning': '6',
#              'pitch_count': '00',
#              'pitch_sequence': '',
#              'visitor_or_home': '1'},
#             {'event_in_game': 53,
#              'event_type': 'sub',
#              'sub_batting_order': '0',
#              'sub_id': 'fienc001',
#              'sub_name': '"Casey Fien"',
#              'sub_position': '1',
#              'sub_team': '0'},
#             {'batter_id': 'espid001',
#              'event': '36(1)1/GDP',
#              'event_in_game': 54,
#              'event_type': 'play',
#              'inning': '6',
#              'pitch_count': '10',
#              'pitch_sequence': '.1BX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'maldm001',
#              'event': 'K',
#              'event_in_game': 55,
#              'event_type': 'play',
#              'inning': '6',
#              'pitch_count': '02',
#              'pitch_sequence': 'CSS',
#              'visitor_or_home': '1'},
#             {'batter_id': 'valed001',
#              'event': 'NP',
#              'event_in_game': 56,
#              'event_type': 'play',
#              'inning': '7',
#              'pitch_count': '00',
#              'pitch_sequence': '',
#              'visitor_or_home': '0'},
#             {'event_in_game': 57,
#              'event_type': 'sub',
#              'sub_batting_order': '0',
#              'sub_id': 'norrb001',
#              'sub_name': '"Bud Norris"',
#              'sub_position': '1',
#              'sub_team': '1'},
#             {'batter_id': 'valed001',
#              'event': 'S9/L',
#              'event_in_game': 58,
#              'event_type': 'play',
#              'inning': '7',
#              'pitch_count': '01',
#              'pitch_sequence': '.CX',
#              'visitor_or_home': '0'},
#             {'batter_id': 'dysoj001',
#              'event': 'HP.1-2',
#              'event_in_game': 59,
#              'event_type': 'play',
#              'inning': '7',
#              'pitch_count': '02',
#              'pitch_sequence': 'FFH',
#              'visitor_or_home': '0'},
#             {'batter_id': 'zunim001',
#              'event': 'K',
#              'event_in_game': 60,
#              'event_type': 'play',
#              'inning': '7',
#              'pitch_count': '32',
#              'pitch_sequence': 'SBCBBT',
#              'visitor_or_home': '0'},
#             {'batter_id': 'hereg002',
#              'event': '65(2)/FO/G.1-2',
#              'event_in_game': 61,
#              'event_type': 'play',
#              'inning': '7',
#              'pitch_count': '00',
#              'pitch_sequence': 'X',
#              'visitor_or_home': '0'},
#             {'batter_id': 'seguj002',
#              'event': '64(1)/FO/G+',
#              'event_in_game': 62,
#              'event_type': 'play',
#              'inning': '7',
#              'pitch_count': '00',
#              'pitch_sequence': 'X',
#              'visitor_or_home': '0'},
#             {'batter_id': 'escoy001',
#              'event': 'S1/G',
#              'event_in_game': 63,
#              'event_type': 'play',
#              'inning': '7',
#              'pitch_count': '12',
#              'pitch_sequence': 'BSSX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'calhk001',
#              'event': 'HR/89/F.1-H',
#              'event_in_game': 64,
#              'event_type': 'play',
#              'inning': '7',
#              'pitch_count': '11',
#              'pitch_sequence': 'FBX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'troum001',
#              'event': '13/G-',
#              'event_in_game': 65,
#              'event_type': 'play',
#              'inning': '7',
#              'pitch_count': '00',
#              'pitch_sequence': 'X',
#              'visitor_or_home': '1'},
#             {'batter_id': 'pujoa001',
#              'event': '63/G+',
#              'event_in_game': 66,
#              'event_type': 'play',
#              'inning': '7',
#              'pitch_count': '12',
#              'pitch_sequence': 'CSBFX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'cronc002',
#              'event': 'K',
#              'event_in_game': 67,
#              'event_type': 'play',
#              'inning': '7',
#              'pitch_count': '02',
#              'pitch_sequence': 'CFS',
#              'visitor_or_home': '1'},
#             {'batter_id': 'hanim001',
#              'event': 'NP',
#              'event_in_game': 68,
#              'event_type': 'play',
#              'inning': '8',
#              'pitch_count': '00',
#              'pitch_sequence': '',
#              'visitor_or_home': '0'},
#             {'event_in_game': 69,
#              'event_type': 'sub',
#              'sub_batting_order': '0',
#              'sub_id': 'baila001',
#              'sub_name': '"Andrew Bailey"',
#              'sub_position': '1',
#              'sub_team': '1'},
#             {'batter_id': 'hanim001',
#              'event': '9/F',
#              'event_in_game': 70,
#              'event_type': 'play',
#              'inning': '8',
#              'pitch_count': '22',
#              'pitch_sequence': '.BBFFFX',
#              'visitor_or_home': '0'},
#             {'batter_id': 'canor001',
#              'event': '5/L',
#              'event_in_game': 71,
#              'event_type': 'play',
#              'inning': '8',
#              'pitch_count': '12',
#              'pitch_sequence': 'CFBX',
#              'visitor_or_home': '0'},
#             {'batter_id': 'cruzn002',
#              'event': 'K',
#              'event_in_game': 72,
#              'event_type': 'play',
#              'inning': '8',
#              'pitch_count': '12',
#              'pitch_sequence': 'SSBS',
#              'visitor_or_home': '0'},
#             {'batter_id': 'maybc001',
#              'event': 'NP',
#              'event_in_game': 73,
#              'event_type': 'play',
#              'inning': '8',
#              'pitch_count': '00',
#              'pitch_sequence': '',
#              'visitor_or_home': '1'},
#             {'event_in_game': 74,
#              'event_type': 'sub',
#              'sub_batting_order': '0',
#              'sub_id': 'overd001',
#              'sub_name': '"Dillon Overton"',
#              'sub_position': '1',
#              'sub_team': '0'},
#             {'batter_id': 'maybc001',
#              'event': '8/F',
#              'event_in_game': 75,
#              'event_type': 'play',
#              'inning': '8',
#              'pitch_count': '11',
#              'pitch_sequence': '.BSX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'simma001',
#              'event': 'S4/G',
#              'event_in_game': 76,
#              'event_type': 'play',
#              'inning': '8',
#              'pitch_count': '11',
#              'pitch_sequence': 'FBX',
#              'visitor_or_home': '1'},
#             {'batter_id': 'espid001',
#              'event': 'K+SB2',
#              'event_in_game': 77,
#              'event_type': 'play',
#              'inning': '8',
#              'pitch_count': '02',
#              'pitch_sequence': 'TS1>S',
#              'visitor_or_home': '1'},
#             {'batter_id': 'maldm001',
#              'event': 'K',
#              'event_in_game': 78,
#              'event_type': 'play',
#              'inning': '8',
#              'pitch_count': '02',
#              'pitch_sequence': 'CSS',
#              'visitor_or_home': '1'},
#             {'batter_id': 'seagk001',
#              'event': 'NP',
#              'event_in_game': 79,
#              'event_type': 'play',
#              'inning': '9',
#              'pitch_count': '00',
#              'pitch_sequence': '',
#              'visitor_or_home': '0'},
#             {'event_in_game': 80,
#              'event_type': 'sub',
#              'sub_batting_order': '0',
#              'sub_id': 'parkb001',
#              'sub_name': '"Blake Parker"',
#              'sub_position': '1',
#              'sub_team': '1'},
#             {'batter_id': 'seagk001',
#              'event': '63/G',
#              'event_in_game': 81,
#              'event_type': 'play',
#              'inning': '9',
#              'pitch_count': '22',
#              'pitch_sequence': '.BCCBX',
#              'visitor_or_home': '0'},
#             {'batter_id': 'valed001',
#              'event': 'E5/TH/G',
#              'event_in_game': 82,
#              'event_type': 'play',
#              'inning': '9',
#              'pitch_count': '22',
#              'pitch_sequence': 'BBSFX',
#              'visitor_or_home': '0'},
#             {'batter_id': 'dysoj001',
#              'event': 'K',
#              'event_in_game': 83,
#              'event_type': 'play',
#              'inning': '9',
#              'pitch_count': '12',
#              'pitch_sequence': 'BFFFS',
#              'visitor_or_home': '0'},
#             {'batter_id': 'zunim001',
#              'event': 'DI.1-2',
#              'event_in_game': 84,
#              'event_type': 'play',
#              'inning': '9',
#              'pitch_count': '00',
#              'pitch_sequence': '>B',
#              'visitor_or_home': '0'},
#             {'batter_id': 'zunim001',
#              'event': '5/P',
#              'event_in_game': 85,
#              'event_type': 'play',
#              'inning': '9',
#              'pitch_count': '12',
#              'pitch_sequence': '>B.CCFX',
#              'visitor_or_home': '0'}],
#  'home_starters': [{'order': '1', 'player_id': 'escoy001', 'position': '5'},
#                    {'order': '2', 'player_id': 'calhk001', 'position': '9'},
#                    {'order': '3', 'player_id': 'troum001', 'position': '8'},
#                    {'order': '4', 'player_id': 'pujoa001', 'position': '10'},
#                    {'order': '5', 'player_id': 'cronc002', 'position': '3'},
#                    {'order': '6', 'player_id': 'maybc001', 'position': '7'},
#                    {'order': '7', 'player_id': 'simma001', 'position': '6'},
#                    {'order': '8', 'player_id': 'espid001', 'position': '4'},
#                    {'order': '9', 'player_id': 'maldm001', 'position': '2'},
#                    {'order': '0', 'player_id': 'chavj001', 'position': '1'}],
#  'id': 'ANA201704070',
#  'info': {'attendance': '43911',
#           'date': '2017/04/07',
#           'daynight': 'night',
#           'fieldcond': 'unknown',
#           'hometeam': 'ANA',
#           'howscored': 'park',
#           'lp': 'gally001',
#           'number': '0',
#           'oscorer': 'munse701',
#           'pitches': 'pitches',
#           'precip': 'unknown',
#           'save': '',
#           'site': 'ANA01',
#           'sky': 'cloudy',
#           'starttime': '7:08PM',
#           'temp': '65',
#           'timeofgame': '176',
#           'ump1b': 'emmep901',
#           'ump2b': 'onorb901',
#           'ump3b': 'wolcq901',
#           'umphome': 'segac901',
#           'usedh': 'true',
#           'visteam': 'SEA',
#           'winddir': 'torf',
#           'windspeed': '7',
#           'wp': 'chavj001'},
#  'version': '2',
#  'visiting_starters': [{'order': '1', 'player_id': 'seguj002', 'position': '6'},
#                        {'order': '2', 'player_id': 'hanim001', 'position': '9'},
#                        {'order': '3', 'player_id': 'canor001', 'position': '4'},
#                        {'order': '4',
#                         'player_id': 'cruzn002',
#                         'position': '10'},
#                        {'order': '5', 'player_id': 'seagk001', 'position': '5'},
#                        {'order': '6', 'player_id': 'valed001', 'position': '3'},
#                        {'order': '7', 'player_id': 'dysoj001', 'position': '8'},
#                        {'order': '8', 'player_id': 'zunim001', 'position': '2'},
#                        {'order': '9', 'player_id': 'hereg002', 'position': '7'},
#                        {'order': '0',
#                         'player_id': 'gally001',
#                         'position': '1'}]}

# %% [markdown]
# # ALL oLD STUFF BELOW HERE

# %%
debug = 0

yeararray = [1921, 1922, 1925, 1927, 1928]

for i in np.linspace(1930,2016,87):
    yeararray.append(i)

years_with_derived = []
for i in np.linspace(1942,1959,18):
    years_with_derived.append(i)
for i in np.linspace(1962,1968,7):
    years_with_derived.append(i)
for i in np.linspace(1971,1973,3):
    years_with_derived.append(i)
    
for thisyear in yeararray:
    allgames = []
    print('Starting to parse the year {0:.0f}'.format(thisyear))
    filename = 'raw/events_raw_{0:.0f}.json'.format(thisyear)
    print(filename)    
    with open(filename,'r') as f:
        games = json.load(f)
    if (thisyear in years_with_derived):
        derived_filename = 'with_derived/events_with_derived_{0:.0f}.json'.format(thisyear)
        print(derived_filename)
        with open(derived_filename,'r') as f:
            games_derived = json.load(f)
        games = games + games_derived
    allgames = allgames + games
    print('Data loaded for {0:.0f}: {1:,.0f} games'.format(thisyear, len(allgames)))
    print('...')
        
#    for i in (4,9,24,35,323,352,378):
    for i in range(0, len(allgames)):
        if ((np.mod(i,500) == 0) | (i == len(allgames)-1)):
            print('Parsing game number {0:,.0f}: {1:}'.format(i, allgames[i]['id']))

#        if (debug > 0):
#            print('\n')
#            print('Parsing game number {0:,.0f}: {1:}'.format(i, allgames[i]['id']))

        if (allgames[i]['events'][0]['event_type'] == 'com'):
            current_comment = allgames[i]['events'][0]['comment']
            first_appearance = 0
        else:
            current_comment = ''
            first_appearance = -1
            
        for j in range(1,len(allgames[i]['events'])-1):
            if (allgames[i]['events'][j]['event_type'] == 'com'):
                if (allgames[i]['events'][j-1]['event_type'] != 'com'):
                    first_appearance = j
                if (allgames[i]['events'][j]['comment'][0] == '"'):
                    allgames[i]['events'][j]['comment'] = allgames[i]['events'][j]['comment'][1:]
                if (allgames[i]['events'][j]['comment'][len(allgames[i]['events'][j]['comment'])-1] == '"'):
                    allgames[i]['events'][j]['comment'] = allgames[i]['events'][j]['comment'][:-1]
                if (j > first_appearance):
                    current_comment += ' '
                current_comment += allgames[i]['events'][j]['comment']
                if (allgames[i]['events'][j+1]['event_type'] != 'com'):
                    allgames[i]['events'][first_appearance]['comment'] = current_comment
                    current_comment = ''
        
        lastrow = len(allgames[i]['events'])-1
        if (allgames[i]['events'][lastrow]['event_type'] == 'com'):
            if (lastrow > first_appearance):
                current_comment += ' '
            current_comment += allgames[i]['events'][lastrow]['comment']
            allgames[i]['events'][first_appearance]['comment'] = current_comment
        
        if (allgames[i]['events'][0]['event_type'] == 'com'):
            allgames[i]['info']['comment'] = allgames[i]['events'][0]['comment']
            
        for k in range(0,len(allgames[i]['events'])-1):
            if ((allgames[i]['events'][k]['event_type'] != 'com') & (allgames[i]['events'][k+1]['event_type'] == 'com')):
                allgames[i]['events'][k]['comment'] = allgames[i]['events'][k+1]['comment']
        
        counter = 0
        allgames[i]['new_events'] = list()
        
        for m in range(0, len(allgames[i]['events'])):
            if (allgames[i]['events'][m]['event_type'] != 'com'):
                allgames[i]['new_events'].append(allgames[i]['events'][m])
                allgames[i]['new_events'][counter]['new_event_in_game'] = counter + 1
                counter = counter + 1
        
        for p in range(0, len(allgames[i]['new_events'])):
            del allgames[i]['new_events'][p]['event_in_game']
            allgames[i]['new_events'][p]['event_in_game'] = allgames[i]['new_events'][p]['new_event_in_game']
            del allgames[i]['new_events'][p]['new_event_in_game']
            
        allgames[i]['events'] = allgames[i]['new_events']
        
#        for w in range(0, len(allgames[i]['events'])):
#            print(allgames[i]['events'][w]['event_in_game'])

    print('Saving file...')
    with open('events_json/events_{0:.0f}.json'.format(thisyear),'w') as f:
        json.dump(allgames, f)
print('Done')

# %%
column_list = ['event_id', 'gameID', 'event_in_game', 'event_type', 'inning', 'visitor_or_home', 'batter_id']
column_list += ['pitch_count', 'pitch_sequence', 'event', 'comment', 'sub_team', 'sub_id', 'sub_batting_order', 'sub_position']#, 'gameID']

events_df = pandas.DataFrame(columns=column_list)
gameinfo_df = pandas.DataFrame(columns=column_list)

allgames = []
yeararray = [1921]
#yeararray = [1921, 1922, 1925, 1927, 1928]
#for i in np.linspace(1930,2016,87):
#    yeararray.append(i)

years_with_derived = []
for i in np.linspace(1942,1959,18):
    years_with_derived.append(i)
for i in np.linspace(1962,1968,7):
    years_with_derived.append(i)
for i in np.linspace(1971,1973,3):
    years_with_derived.append(i)
    
for thisyear in yeararray:
    print('Starting to parse the year {0:.0f}'.format(thisyear))
    filename = 'raw/events_raw_{0:.0f}.json'.format(thisyear)
    print(filename)    
    with open(filename,'r') as f:
        games = json.load(f)
    if (thisyear in years_with_derived):
        derived_filename = 'with_derived/events_with_derived_{0:.0f}.json'.format(thisyear)
        print(derived_filename)
        with open(derived_filename,'r') as f:
            games_derived = json.load(f)
        games = games + games_derived
    allgames = allgames + games
    print('Data loaded for {0:.0f}: {1:,.0f} games'.format(thisyear, len(allgames)))
    print('...')
        
    #for i in (24,35,323,352,378):
    for i in range(0, len(games)):
#        print(len(allgames[i]['events']))        
        game_events_df = pandas.DataFrame.from_records(allgames[i]['events'])
        game_events_df['event_id'] = -1
        game_events_df['gameID'] = allgames[i]['id']
        if ((np.mod(i,100) == 0) | (i == len(allgames)-1)):
            print('Parsing game number {0:,.0f}: {1:}'.format(i, allgames[i]['id']))

        for varname in ('comment', 'sub_team', 'sub_id', 'sub_batting_order', 'sub_position'):
            if (varname not in game_events_df):                # if a game had no comments and/or substitutes, fill with blanks
                game_events_df[varname] = ''
        game_events_df = game_events_df[column_list]

        game_events_df['inning'] = pandas.to_numeric(game_events_df['inning'], errors='coerce')
        game_events_df['visitor_or_home'] = pandas.to_numeric(game_events_df['visitor_or_home'], errors='coerce')
        game_events_df['sub_team'] = pandas.to_numeric(game_events_df['sub_team'], errors='coerce')
        game_events_df['sub_batting_order'] = pandas.to_numeric(game_events_df['sub_batting_order'], errors='coerce')
        game_events_df['sub_position'] = pandas.to_numeric(game_events_df['sub_position'], errors='coerce')
        game_events_df = game_events_df.set_index('event_in_game')
        game_events_df = game_events_df.fillna('')

        current_comment = ''
        first_appearance = -1
        for eig, thisevent in game_events_df.iterrows():
            if (thisevent['event_type'] == 'com'):
    #            print(eig, thisevent['comment'])
                if (eig == 1):
                    game_events_df['event_type'].set_value(1, 'gameinfo')
                    first_appearance = 1
                elif (game_events_df['event_type'].loc[eig-1] != 'com'):
                    first_appearance = eig
                current_comment += ' ' + thisevent['comment']
            else:
                if (current_comment != ''):
                    current_comment = current_comment.replace('"','')
                    game_events_df['comment'].set_value(first_appearance-1, current_comment)
    #                print(first_appearance,current_comment,'\n')                
                current_comment = ''
                first_appearance = -1

        # do it again to take care of the case when the last event in a game is a comment
        if (game_events_df['event_type'].iloc[-1] == 'com'):
            current_comment = current_comment.replace('"','')
            game_events_df['comment'].set_value(first_appearance-1, current_comment)

        game_events_df = game_events_df[game_events_df['event_type'] != 'com']        

        game_gameinfo_df = game_events_df[game_events_df['event_type'] == 'gameinfo']
        game_events_df = game_events_df[game_events_df['event_type'] != 'gameinfo']

        gameinfo_df = pandas.concat((gameinfo_df, game_gameinfo_df))
        # re-index now that we are missing rows (again, counting events in the game starting from 1)
        game_events_df = game_events_df.reset_index(drop=True)
        game_events_df['event_in_game'] = game_events_df.index.values+1
        game_events_df = game_events_df.set_index('event_in_game')
        
        if (len(game_gameinfo_df) > 0):
#            print('Inserting extra information in game {0:,.0f}, {1:}'.format(i, allgames[i]['id']))
            allgames[i]['info']['comment'] = game_gameinfo_df['comment'].values.tolist()[0]

        allgames[i]['events'] = game_events_df.to_dict()

#print('done')                                    
#    print('Writing files...')
#    gameinfo_df.to_csv('games/game_info_extra_{0:.0f}.csv'.format(thisyear))
#    events_df.to_csv('events_data/events_{0:.0f}.csv'.format(thisyear))
gameinfo_df

# %%
column_list = ['event_id', 'gameID', 'event_in_game', 'event_type', 'inning', 'visitor_or_home', 'batter_id']
column_list += ['pitch_count', 'pitch_sequence', 'event', 'comment', 'sub_team', 'sub_id', 'sub_batting_order', 'sub_position']#, 'gameID']

events_df = pandas.DataFrame(columns=column_list)

#for i in range(0, len(allgames)):
global_count_offset = 0
#for i in (323, 352, 378):
for i in range(0,36):
#for i in range(0, len(allgames)):
    game_events_df = pandas.DataFrame.from_records(allgames[i]['events'])
    game_events_df['event_id'] = -1
    game_events_df['gameID'] = allgames[i]['id']
    for varname in ('comment', 'sub_team', 'sub_id', 'sub_batting_order', 'sub_position'):
        if (varname not in game_events_df):                # if a game had no comments and/or substitutes, fill with blanks
            game_events_df[varname] = ''
    game_events_df = game_events_df[column_list]

    game_events_df['inning'] = pandas.to_numeric(game_events_df['inning'], errors='coerce')
    game_events_df['visitor_or_home'] = pandas.to_numeric(game_events_df['visitor_or_home'], errors='coerce')
    game_events_df['sub_team'] = pandas.to_numeric(game_events_df['sub_team'], errors='coerce')
    game_events_df['sub_batting_order'] = pandas.to_numeric(game_events_df['sub_batting_order'], errors='coerce')
    game_events_df['sub_position'] = pandas.to_numeric(game_events_df['sub_position'], errors='coerce')
    game_events_df = game_events_df.set_index('event_in_game')
    game_events_df = game_events_df.fillna('')
    
    if (np.mod(i, 10) == 0):
        print('Parsing game number {0:,.0f}, containing {1:,.0f} events.'.format(i, len(game_events_df)))
    
    # NOTE: this all takes iloc and so goes off of event_in_game, which is a 1-based counter
#    print(game_events_df.tail(1))

    if (game_events_df['event_type'].iloc[1] == 'com'):
        print('COMMENT IN FIRST LINE in game number {0:,.0f}!!!!!!!!!!!!!!!'.format(i))
#        full_comment = game_events_df['comment'].iloc[1] + ' ' + game_events_df['comment'].iloc[2]
#        game_events_df['comment'].set_value(2, full_comment)       
        
    for j in range(len(game_events_df)-1, -2, -1):   # iterate from last to first: be sure to do something if the first event is a comment
        if (game_events_df['event_type'].iloc[j] == 'com'):
#            print(j, game_events_df.iloc[j])
            full_comment = game_events_df['comment'].iloc[j]
            if (j < len(game_events_df)-1):
                full_comment = full_comment + ' ' + game_events_df['comment'].iloc[j+1]
#            if (full_comment[0] == '"'):
#                full_comment = full_comment[1:]
#            if (full_comment[-1] == '"'):
#                full_comment = full_comment[:-1]
            if (game_events_df['comment'].iloc[j-1] != ''):
                game_events_df['comment'].set_value(j, full_comment)
                
#        print(game_events_df.iloc[1])
        
    # drop comment rows
    game_events_df = game_events_df[game_events_df['event_type'] != 'com']

    # re-index now that we are missing rows (again, counting events in the game starting from 1)
    game_events_df = game_events_df.reset_index(drop=True)
    game_events_df['event_in_game'] = game_events_df.index.values+1
    #game_events_df = game_events_df.set_index('event_in_game')

    game_events_df['event_id'] = game_events_df['event_in_game'] + global_count_offset
   
    events_df = pandas.concat((events_df, game_events_df))
    
    global_count_offset += len(game_events_df)    



events_df = events_df[column_list]
events_df = events_df.set_index('event_id')
#events_df.to_csv('events/events_1921.csv')
#events_df
events_df[events_df['comment'] != '']

#print('Done')

# %%
column_list = ['event_id', 'gameID', 'event_in_game', 'event_type', 'inning', 'visitor_or_home', 'batter_id']
column_list += ['pitch_count', 'pitch_sequence', 'event', 'comment', 'sub_team', 'sub_id', 'sub_batting_order', 'sub_position']#, 'gameID']

events_df = pandas.DataFrame(columns=column_list)
#events_df = events_df.set_index('event_id')

globalcount = 0
for i in range(0, len(allgames)):
    if (np.mod(i, 100) == 0):
        print(i)
    game_events_df = pandas.DataFrame.from_records(allgames[i]['events'])
    game_events_df['event_id'] = globalcount + game_events_df['event_in_game']
    game_events_df['gameID'] = allgames[i]['id']


    
    game_events_df = game_events_df[column_list]
#    game_events_df = game_events_df.set_index('event_in_game')

    #game_events_df[game_events_df['event_type'] == 'comment'].head(5)
    
    events_df = pandas.concat((events_df, game_events_df))
    globalcount = globalcount + len(game_events_df)

events_df['event_in_game'] = pandas.to_numeric(events_df['event_in_game'], errors='coerce')
events_df = events_df.set_index('event_id', drop=True)
#events_df = events_df.drop('event_in_game', axis=1)
print('Done')

# %%
events_df['inning'] = pandas.to_numeric(events_df['inning'], errors='coerce')
events_df['visitor_or_home'] = pandas.to_numeric(events_df['visitor_or_home'], errors='coerce')
events_df['sub_team'] = pandas.to_numeric(events_df['sub_team'], errors='coerce')
events_df['sub_batting_order'] = pandas.to_numeric(events_df['sub_batting_order'], errors='coerce')
events_df['sub_position'] = pandas.to_numeric(events_df['sub_position'], errors='coerce')
events_df = events_df.fillna('')          
print('ok')

# %%
events_df
#events_df[events_df['event_type'] == 'com']

# %%
column_list = ['event_in_game', 'event_type', 'inning', 'home_or_visitor', 'batterID']
column_list += ['pitch_count', 'pitch_sequence', 'event', 'comment', 'sub_team', 'sub_batting_order', 'sub_position']#, 'gameID']

for i in range(0,1):
#for i in range(0,len(allgames)):
    thisgamedict = allgames[i]
    this_game_events_df = pandas.DataFrame(thisgamedict['events'], columns=column_list)
    this_game_events_df = this_game_events_df.set_index('event_in_game')
this_game_events_df[this_game_events_df['comment'] != '']

# %%
column_list = ['event_in_game', 'event_type', 'inning', 'home_or_visitor', 'batterID']
column_list += ['pitch_count', 'pitch_sequence', 'event', 'comment', 'sub_team', 'sub_batting_order', 'sub_position']#, 'gameID']

show_columns_for_weirdness = ['event_in_game', 'inning', 'home_or_visitor', 'event', 'comment']

for i in range(0,len(allgames)):
    thisgamedict = allgames[i]
    thisgameevents_df = pandas.DataFrame(thisgamedict['events'], columns=column_list)
    if (numpy.mod(i,100) == 0):
        print('processing game {0:,.0f}...'.format(i))
    for j in range(0,len(thisgameevents_df)): #- 1):
        if (thisgameevents_df.iloc[j]['event_type'] != 'play'):
            thisgameevents_df.iloc[j]['inning'] = thisgameevents_df.iloc[j-1]['inning']
            thisgameevents_df.iloc[j]['home_or_visitor'] = thisgameevents_df.iloc[j-1]['home_or_visitor']
            
        if (thisgameevents_df.iloc[j-1]['event_type'] not in ('play','sub')):
            thisgameevents_df.iloc[j]['comment'] = thisgameevents_df.iloc[j-1]['comment'] + ' ' + thisgameevents_df.iloc[j]['comment']

    thisgameevents_df = thisgameevents_df[(thisgameevents_df['event_type'] == 'play') | (thisgameevents_df['event_type'] == 'sub')]
    thisgameevents_df = thisgameevents_df.drop('event_in_game',axis=1)
    thisgameevents_df = thisgameevents_df.reset_index(drop=True)
    thisgameevents_df.index.name = 'event_in_game'
    allgames[i]['events'] = thisgameevents_df.reset_index().values.tolist()

print('preparing to save file...')
#thisgameevents_df
with open('events_json/events_1930.json','w') as f:
    json.dump(allgames, f)
print('done')

# %%
    # replace event types with number codes for fastness
#    thisgameevents_df['event_type'] = numpy.where((thisgameevents_df['event_type'] == 'play'),0,(thisgameevents_df['event_type']))
#    thisgameevents_df['event_type'] = numpy.where((thisgameevents_df['event_type'] == 'sub'),1,(thisgameevents_df['event_type']))
#    thisgameevents_df['event_type'] = numpy.where((thisgameevents_df['event_type'] == 'com'),2,(thisgameevents_df['event_type']))
#    thisgameevents_df['event_type'] = numpy.where((thisgameevents_df['event_type'] == 'badj'),3,(thisgameevents_df['event_type']))
#    thisgameevents_df['event_type'] = numpy.where((thisgameevents_df['event_type'] == 'padj'),4,(thisgameevents_df['event_type']))
#    thisgameevents_df['event_type'] = numpy.where((thisgameevents_df['event_type'] == 'badj'),5,(thisgameevents_df['event_type']))
#    thisgameevents_df['event_type'] = pandas.to_numeric(thisgameevents_df['event_type'])
