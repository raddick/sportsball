# %%
import json
import numpy
import pandas
from pprint import pprint
pandas.options.display.max_colwidth = -1

# %%
# runs in about 5 minutes
with open('events_raw.json','r') as f:
    allgames = json.load(f)
print('ok')
#pprint(allgames[2])   
allgames_bk = allgames
# Out:
# ok

# %%
column_list = ['event_in_game', 'event_type', 'inning', 'home_or_visitor', 'batterID']
column_list += ['pitch_count', 'pitch_sequence', 'event', 'comment', 'sub_batting_order', 'sub_position']#, 'gameID']

show_columns_for_weirdness = ['event_in_game', 'inning', 'home_or_visitor', 'event', 'comment']

for i in range(0,len(allgames)):
    thisgamedict = allgames[i]
    thisgameevents_df = pandas.DataFrame(thisgamedict['events'], columns=column_list)
    inning = 1
    if (numpy.mod(i,1000) == 0):
        print('processing game {0:,.0f}...'.format(i))
    for j in range(0,len(thisgameevents_df)): #- 1):
        if (thisgameevents_df.iloc[j]['event_type'] != 'play'):
            thisgameevents_df.iloc[j]['inning'] = thisgameevents_df.iloc[j-1]['inning']
        if (thisgameevents_df.iloc[j-1]['event_type'] not in ('play','sub')):
            thisgameevents_df.iloc[j]['comment'] = thisgameevents_df.iloc[j-1]['comment'] + ' ' + thisgameevents_df.iloc[j]['comment']
#            if (thisgameevents_df.iloc[j]['event_type'] in ('badj', 'padj', 'ladj')):
#                print(allgames[i]['id'])
#                print('-------------')
#                print(thisgameevents_df[show_columns_for_weirdness].iloc[j])
#                print('\n')
    thisgameevents_df = thisgameevents_df[(thisgameevents_df['event_type'] == 'play') | (thisgameevents_df['event_type'] == 'sub')]
    thisgameevents_df = thisgameevents_df.drop('event_in_game',axis=1)
    thisgameevents_df = thisgameevents_df.reset_index(drop=True)
    thisgameevents_df.index.name = 'event_in_game'
    allgames[i]['events'] = thisgameevents_df.reset_index().values.tolist()

print('preparing to save file...')
#thisgameevents_df
with open('events.json','w') as f:
    json.dump(allgames, f, encoding='utf-8')
print('done')
# Out:
# processing game 0...
# processing game 1,000...
# processing game 2,000...
# NY1192508142
# -------------
# event_in_game      64
# inning             6
# home_or_visitor
# event
# comment            "NY Times reported Bentley batted right-handed initially "a strategic move by McGraw to block the catcher's view" "on the ensuing double steal." bentj101
# Name: 63, dtype: object
#
#
# processing game 3,000...
# CHA192808060
# -------------
# event_in_game      105
# inning             10
# home_or_visitor    0
# event
# comment            "$Cedric Durst batted out of turn; Durst pinch ran for Lou" "Gehrig in the fourth lineup spot but batted in the ninth" "spot"
# Name: 104, dtype: object
#
#
# CHA192808060
# -------------
# event_in_game      126
# inning             10
# home_or_visitor    0
# event
# comment            "pbp account ends here
# Name: 125, dtype: object
#
#
# CHA192808060
# -------------
# event_in_game      144
# inning             12
# home_or_visitor    0
# event
# comment            "$Cedric Durst batted out of turn"
# Name: 143, dtype: object
#
#
# CHA192808060
# -------------
# event_in_game      181
# inning             15
# home_or_visitor    0
# event
# comment            "$the White Sox pointed out that Cedric Durst was batting out of turn "but Umpire Bill Dinneen said Durst had a right to bat where he" "was "Yankees won"
# Name: 180, dtype: object
#
#
# PHA192805230
# -------------
# event_in_game      4
# inning             1
# home_or_visitor    0
# event
# comment            "$Joe Judge batted out of turn but made an out"
# Name: 3, dtype: object
#
#
# PHA192805230
# -------------
# event_in_game      10
# inning             1
# home_or_visitor    0
# event
# comment            "$George Sisler batted out of turn but made an out"
# Name: 9, dtype: object
#
#
# PHA192805230
# -------------
# event_in_game      13
# inning             2
# home_or_visitor    0
# event
# comment            "$Muddy Ruel batted out of turn but made an out"
# Name: 12, dtype: object
#
#
# processing game 4,000...
# processing game 5,000...
# BSN193104150
# -------------
# event_in_game      66
# inning             6
# home_or_visitor    0
# event
# comment            "$Alta Cohen batted out of turn but not caught by the Braves"
# Name: 65, dtype: object
#
#
# processing game 6,000...
# NY1193205260
# -------------
# event_in_game      20
# inning             3
# home_or_visitor    0
# event
# comment            "$George Kelly batted out of turn"
# Name: 19, dtype: object
#
#
# NY1193205260
# -------------
# event_in_game      41
# inning             5
# home_or_visitor    0
# event
# comment            "$Al Lopez batted out of turn"
# Name: 40, dtype: object
#
#
# NY1193205260
# -------------
# event_in_game      44
# inning             5
# home_or_visitor    0
# event
# comment            "$George Kelly batted out of turn"
# Name: 43, dtype: object
#
#
# processing game 7,000...
# processing game 8,000...
# BOS193408100
# -------------
# event_in_game      10
# inning             1
# home_or_visitor    0
# event
# comment            "$Bill Dickey and Ben Chapman bat out of turn but the" "Red Sox don't notice until the 5th inning; Yankees" "manager Joe McCarthy made a late lineup change that" "the players missed"
# Name: 9, dtype: object
#
#
# BOS193408100
# -------------
# event_in_game      59
# inning             5
# home_or_visitor    0
# event
# comment            "$Bill Dickey singled but was out for batting out of turn"
# Name: 58, dtype: object
#
#
# processing game 9,000...
# CIN193507310
# -------------
# event_in_game      47
# inning             6
# home_or_visitor
# event
# comment            "$into the overflow crowd" collr101
# Name: 46, dtype: object
#
#
# BOS193605020
# -------------
# event_in_game      6
# inning             1
# home_or_visitor
# event
# comment            "$Plain Dealer reports that today Trosky stayed LH vs LHP" trosh101
# Name: 5, dtype: object
#
#
# processing game 10,000...
# NYA193604290
# -------------
# event_in_game      10
# inning             2
# home_or_visitor
# event
# comment            "$Trosky batted right handed vs. Lefty Gomez." trosh101
# Name: 9, dtype: object
#
#
# processing game 11,000...
# processing game 12,000...
# CHN193906182
# -------------
# event_in_game      8
# inning             1
# home_or_visitor
# event
# comment            "$Due to sore shoulder Galan batted LH vs LHP Tamulis except for sacrifice bunt." galaa101
# Name: 7, dtype: object
#
#
# processing game 13,000...
# processing game 14,000...
# CHA194204260
# -------------
# event_in_game      15
# inning             2
# home_or_visitor    1
# event
# comment            "$Bob Kennedy batted in Bud Sketchley's spot"
# Name: 14, dtype: object
#
#
# processing game 15,000...
# processing game 16,000...
# NY1194305012
# -------------
# event_in_game      19
# inning             2
# home_or_visitor    0
# event
# comment            "$Alex Kampouris batted out of order in Dee Moore's place;" "Dodger manager Leo Durocher noticed and sent Kampouris to" "bat again "Kampouris batted "Newsom; the Giants made no objections to any part of this;" "the end result is that Moore was skipped this time around"
# Name: 18, dtype: object
#
#
# processing game 17,000...
# processing game 18,000...
# processing game 19,000...
# processing game 20,000...
# BSN194809062
# -------------
# event_in_game      63
# inning             5
# home_or_visitor    1
# event
# comment            "$Mike McCormick singled to LF but the Dodgers told HP umpire" "Artie Gore that he had batted out of turn; the Dodgers had" "not noticed even though this was the third time through the" "batting order"
# Name: 62, dtype: object
#
#
# processing game 21,000...
# processing game 22,000...
# BRO195007280
# -------------
# event_in_game      10
# inning             1
# home_or_visitor    0
# event
# comment            "$Duke Snider rounded 2B too far"
# Name: 9, dtype: object
#
#
# processing game 23,000...
# CHN195108011
# -------------
# event_in_game      78
# inning             8
# home_or_visitor    0
# event
# comment            "$Giants manager Leo Durocher insisted that Sal Yvars was the batter" "instead of Davey Williams"
# Name: 77, dtype: object
#
#
# processing game 24,000...
# processing game 25,000...
# processing game 26,000...
# CHA195408130
# -------------
# event_in_game      136
# inning             15
# home_or_visitor    0
# event
# comment            "$Wayne Belardi batted out of turn but made an out"
# Name: 135, dtype: object
#
#
# processing game 27,000...
# processing game 28,000...
# processing game 29,000...
# processing game 30,000...
# processing game 31,000...
# processing game 32,000...
# processing game 33,000...
# processing game 34,000...
# processing game 35,000...
# processing game 36,000...
# processing game 37,000...
# processing game 38,000...
# processing game 39,000...
# CHN196409240
# -------------
# event_in_game      61
# inning             6
# home_or_visitor    1
# event
# comment            "DWS: note that the ladj record accomplishes nothing "Boccabella was already legitimately in this batting slot." "our entry currently and incorrectly charges Boccabella with" "the at bat; that needs to be fixed by special case coding."
# Name: 60, dtype: object
#
#
# processing game 40,000...
# processing game 41,000...
# processing game 42,000...
# processing game 43,000...
# processing game 44,000...
# processing game 45,000...
# processing game 46,000...
# processing game 47,000...
# SE1196904130
# -------------
# event_in_game      70
# inning             5
# home_or_visitor    0
# event
# comment            "$Wilbur Wood and Duane Josephson batted out of turn their first" "time up after entering the game; there was no objection from the" "Pilots and they batted correctly for the rest of the game"
# Name: 69, dtype: object
#
#
# processing game 48,000...
# processing game 49,000...
# processing game 50,000...
# processing game 51,000...
# processing game 52,000...
# BOS197209160
# -------------
# event_in_game      105
# inning             8
# home_or_visitor    1
# event
# comment            "$Dwight Evans batted out of order but since he was retired "protest was made by the Indians"
# Name: 104, dtype: object
#
#
# processing game 53,000...
# processing game 54,000...
# processing game 55,000...
# processing game 56,000...
# CIN197405150
# -------------
# event_in_game      74
# inning             8
# home_or_visitor    0
# event
# comment            "$Garry Maddox batted out of turn in Mike Phillips spot"
# Name: 73, dtype: object
#
#
# processing game 57,000...
# processing game 58,000...
# processing game 59,000...
# processing game 60,000...
# processing game 61,000...
# processing game 62,000...
# SDN197704290
# -------------
# event_in_game      46
# inning             4
# home_or_visitor    0
# event
# comment            "$the Padres missed the chance to cancel the homer because of John Stearns batting" "out of order"
# Name: 45, dtype: object
#
#
# SDN197704290
# -------------
# event_in_game      75
# inning             5
# home_or_visitor    0
# event
# comment            "$the proper batter is Stearns but Harrelson batted"
# Name: 74, dtype: object
#
#
# processing game 63,000...
# processing game 64,000...
# processing game 65,000...
# processing game 66,000...
# processing game 67,000...
# processing game 68,000...
# processing game 69,000...
# ATL198110010
# -------------
# event_in_game      80
# inning             8
# home_or_visitor
# event
# comment            "Debut game for Jose Alvarez" mintg001
# Name: 79, dtype: object
#
#
# processing game 70,000...
# processing game 71,000...
# processing game 72,000...
# processing game 73,000...
# processing game 74,000...
# SEA198306270
# -------------
# event_in_game      25
# inning             2
# home_or_visitor    1
# event
# comment            "$Dave Henderson and Jamie Allen batted out of order" "but nothing was said by the White Sox"
# Name: 24, dtype: object
#
#
# processing game 75,000...
# processing game 76,000...
# processing game 77,000...
# processing game 78,000...
# processing game 79,000...
# processing game 80,000...
# processing game 81,000...
# processing game 82,000...
# processing game 83,000...
# processing game 84,000...
# processing game 85,000...
# processing game 86,000...
# processing game 87,000...
# processing game 88,000...
# processing game 89,000...
# processing game 90,000...
# processing game 91,000...
# processing game 92,000...
# processing game 93,000...
# processing game 94,000...
# processing game 95,000...
# processing game 96,000...
# processing game 97,000...
# processing game 98,000...
# processing game 99,000...
# processing game 100,000...
# processing game 101,000...
# processing game 102,000...
# processing game 103,000...
# processing game 104,000...
# SFN199808080
# -------------
# event_in_game      76
# inning             6
# home_or_visitor    1
# event
# comment            "$Rich Aurilia and Joe Carter batted out of turn"
# Name: 75, dtype: object
#
#
# processing game 105,000...
# MON199809160
# -------------
# event_in_game      1
# inning
# home_or_visitor
# event
# comment            "June 25 castl001
# Name: 0, dtype: object
#
#
# processing game 106,000...
# processing game 107,000...
# BAL200007202
# -------------
# event_in_game      15
# inning             2
# home_or_visitor
# event
# comment            "SS ADDS BADJS FOR BURKHART 12/19/00" burkm001
# Name: 14, dtype: object
#
#
# BOS200004110
# -------------
# event_in_game      29
# inning             2
# home_or_visitor
# event
# comment            "SS ADDED 2 BADJ FOR EVERETT 12/19/00" everc001
# Name: 28, dtype: object
#
#
# BOS200006190
# -------------
# event_in_game      111
# inning             9
# home_or_visitor
# event
# comment            "ADM--SS ADDS POSADA BADJ 12/19/00" posaj001
# Name: 110, dtype: object
#
#
# processing game 108,000...
# CHN200008270
# -------------
# event_in_game      17
# inning             2
# home_or_visitor
# event
# comment            "SS ADDS BADJS FOR WOOD 12/19/00" "GG corrects 2xBADJ for Wood from BADJ-R to BADJ-L 020601" woodk002
# Name: 16, dtype: object
#
#
# CLE200004160
# -------------
# event_in_game      17
# inning             2
# home_or_visitor
# event
# comment            "SS ADDED 3 ALICEA BADJ 12/19/00" alicl001
# Name: 16, dtype: object
#
#
# CLE200005010
# -------------
# event_in_game      75
# inning             8
# home_or_visitor
# event
# comment            "SS ADDS BADJ FOR VIZQUEL 12/19/00" "WE ARE PUTTING IN BADJS HERE AND ON 5/3 FOR VIZQUEL" "TO MATCH UP RIVERA; IT'S AN ASSUMPTION BUT" "BUT WE THINK IT'S RIGHT" vizqo001
# Name: 74, dtype: object
#
#
# CLE200007010
# -------------
# event_in_game      91
# inning             9
# home_or_visitor
# event
# comment            "SS ADDED BADJ 12/19/00" alomr001
# Name: 90, dtype: object
#
#
# HOU200006200
# -------------
# event_in_game      18
# inning             2
# home_or_visitor
# event
# comment            "SS ADDS BARKER BADJS 12/19/00" barkg001
# Name: 17, dtype: object
#
#
# HOU200006250
# -------------
# event_in_game      35
# inning             4
# home_or_visitor
# event
# comment            "SS ADDED BARKER BADJS 12/19/00" barkg001
# Name: 34, dtype: object
#
#
# HOU200008220
# -------------
# event_in_game      20
# inning             2
# home_or_visitor
# event
# comment            "SS ADDS BADJ 12/19/00" woodk002
# Name: 19, dtype: object
#
#
# processing game 109,000...
# NYN200006020
# -------------
# event_in_game      63
# inning             7
# home_or_visitor
# event
# comment            "SS ADDED BADJ 12/19/00" winnr001
# Name: 62, dtype: object
#
#
# OAK200008260
# -------------
# event_in_game      37
# inning             4
# home_or_visitor
# event
# comment            "SS ADDS 3 BADJ FOR WILLIAMS 12/19/00" willb002
# Name: 36, dtype: object
#
#
# PHI200006060
# -------------
# event_in_game      3
# inning             10
# home_or_visitor
# event
# comment            "ej "Phillies coach John Vukovich ejected by HP umpire Tim Timmons sometime in game" winnr001
# Name: 2, dtype: object
#
#
# SEA200004040
# -------------
# event_in_game      4
# inning             1
# home_or_visitor
# event
# comment            "SS ADDED 1ST INN BADJ 12/19/00" everc001
# Name: 3, dtype: object
#
#
# SEA200006190
# -------------
# event_in_game      69
# inning             7
# home_or_visitor
# event
# comment            "SS ADDED BADJ 12/19/00" winnr001
# Name: 68, dtype: object
#
#
# SEA200008280
# -------------
# event_in_game      63
# inning             8
# home_or_visitor
# event
# comment            "SS ADDS BADJ 12/19/00" willb002
# Name: 62, dtype: object
#
#
# TBA200006090
# -------------
# event_in_game      5
# inning             1
# home_or_visitor
# event
# comment            "SS ADDS 1st inning Winn badj 12/19/00" winnr001
# Name: 4, dtype: object
#
#
# TBA200006130
# -------------
# event_in_game      7
# inning             1
# home_or_visitor
# event
# comment            "SS ADDED BADJ 12/19/00" winnr001
# Name: 6, dtype: object
#
#
# TBA200006130
# -------------
# event_in_game      25
# inning             2
# home_or_visitor
# event
# comment            "SS ADDED BADJ 12/19/00" winnr001
# Name: 24, dtype: object
#
#
# TBA200006270
# -------------
# event_in_game      7
# inning             1
# home_or_visitor
# event
# comment            "SS ADDED 1ST INN BADJ 12/19/00" winnr001
# Name: 6, dtype: object
#
#
# TBA200006290
# -------------
# event_in_game      9
# inning             1
# home_or_visitor
# event
# comment            "SS ADDED 1ST INNING BADJ 12/19/00" winnr001
# Name: 8, dtype: object
#
#
# TOR200005050
# -------------
# event_in_game      46
# inning             4
# home_or_visitor
# event
# comment            "SS ADDED BADJ 12/19/00" alomr001
# Name: 45, dtype: object
#
#
# processing game 110,000...
# processing game 111,000...
# processing game 112,000...
# processing game 113,000...
# processing game 114,000...
# BAL200308160
# -------------
# event_in_game      10
# inning             1
# home_or_visitor    1
# event
# comment            "$Tony Batista batted out of turn"
# Name: 9, dtype: object
#
#
# processing game 115,000...
# processing game 116,000...
# processing game 117,000...
# BOS200408290
# -------------
# event_in_game      64
# inning             7
# home_or_visitor
# event
# comment            "ej "Tigers Manager Alan Trammell ejected by HP umpire Bill Welke" yound001
# Name: 63, dtype: object
#
#
# CHN200406080
# -------------
# event_in_game      79
# inning             8
# home_or_visitor
# event
# comment            "ej "$second pitch check swing called strike by" "3B umpire Alfonzo Marquez; Ronny Cedeno argued with HP" "umpire Rick Reed and then smacked his bat on" "the plate "Reed; Cedeno started for the dugout "and sprayed him with whatever was in his mouth" tagus001
# Name: 78, dtype: object
#
#
# KCA200404240
# -------------
# event_in_game      38
# inning             5
# home_or_visitor
# event
# comment            "$May left with injured leg after four pitches to Bowen" bower002
# Name: 37, dtype: object
#
#
# processing game 118,000...
# OAK200407010
# -------------
# event_in_game      60
# inning             6
# home_or_visitor
# event
# comment            "$Kielty batted right because of sore ribs" kielb001
# Name: 59, dtype: object
#
#
# MON200405220
# -------------
# event_in_game      16
# inning             2
# home_or_visitor
# event
# comment            "$Everitt batted right-handed due to injury" everc001
# Name: 15, dtype: object
#
#
# MON200405240
# -------------
# event_in_game      17
# inning             2
# home_or_visitor
# event
# comment            "$Everitt batting right-handed due to injury" everc001
# Name: 16, dtype: object
#
#
# MON200405260
# -------------
# event_in_game      11
# inning             1
# home_or_visitor
# event
# comment            "$Carl Everitt batted right-handed due to injury" everc001
# Name: 10, dtype: object
#
#
# MON200405280
# -------------
# event_in_game      16
# inning             2
# home_or_visitor
# event
# comment            "$Everitt batted right-handed due to injury" everc001
# Name: 15, dtype: object
#
#
# MON200405290
# -------------
# event_in_game      16
# inning             2
# home_or_visitor
# event
# comment            "$Everitt batted right-handed due to injury" everc001
# Name: 15, dtype: object
#
#
# processing game 119,000...
# BOS200506180
# -------------
# event_in_game      12
# inning             1
# home_or_visitor
# event
# comment            "$first pitch hit Ryan Doumit "arm into it intentionally; minimal argument from the Pirates" doumr001
# Name: 11, dtype: object
#
#
# processing game 120,000...
# PHI200507080
# -------------
# event_in_game      50
# inning             4
# home_or_visitor
# event
# comment            "$foul ball off plate hit Geary in face "who completed the strikeout hitting right-handed" liebj001
# Name: 49, dtype: object
#
#
# processing game 121,000...
# BOS200607300
# -------------
# event_in_game      36
# inning             3
# home_or_visitor
# event
# comment            "$Red Sox Trot Nixon left the game due to an injured right forearm" penaw001
# Name: 35, dtype: object
#
#
# processing game 122,000...
# processing game 123,000...
# WAS200609190
# -------------
# event_in_game      117
# inning             9
# home_or_visitor
# event
# comment            "$Pena batted right against the right-handed Bergmann due to a thumb injury" penab002
# Name: 116, dtype: object
#
#
# processing game 124,000...
# processing game 125,000...
# TOR200705310
# -------------
# event_in_game      41
# inning             6
# home_or_visitor
# event
# comment            "$Erstad hurt ankle swinging and missing at 2-1 pitch." "Popping sound heard from dugout" terrl001
# Name: 40, dtype: object
#
#
# TOR200709010
# -------------
# event_in_game      19
# inning             2
# home_or_visitor    1
# event
# comment            "$Lyle Overbay batted out of turn "not point out the mistake"
# Name: 18, dtype: object
#
#
# TOR200709010
# -------------
# event_in_game      26
# inning             2
# home_or_visitor    1
# event
# comment            "$Aaron Hill doubled "did point out this mistake and Hill was called out; However "correct batter at this point was actually Gregg Zaun and he is the one" "who should have been called out; the umpires called the wrong man" "out."
# Name: 25, dtype: object
#
#
# processing game 126,000...
# BAL200805010
# -------------
# event_in_game      42
# inning             5
# home_or_visitor
# event
# comment            "Rays center fielder B. J. Upton left the game due to an injured neck/shoulder" haynn001
# Name: 41, dtype: object
#
#
# processing game 127,000...
# SFN200804120
# -------------
# event_in_game      15
# inning             2
# home_or_visitor
# event
# comment            "Debut game for John Bowker" ortmd001
# Name: 14, dtype: object
#
#
# processing game 128,000...
# processing game 129,000...
# processing game 130,000...
# BOS201005070
# -------------
# event_in_game      77
# inning             7
# home_or_visitor
# event
# comment            "Red Sox catcher Jason Varitek left the game due to a left forearm contusion" swisn001
# Name: 76, dtype: object
#
#
# processing game 131,000...
# processing game 132,000...
# processing game 133,000...
# COL201109180
# -------------
# event_in_game      64
# inning             6
# home_or_visitor
# event
# comment            "$Pedro Sandoval hit left-handed due to a sore left shoulder" sandp001
# Name: 63, dtype: object
#
#
# processing game 134,000...
# OAK201109040
# -------------
# event_in_game      94
# inning             8
# home_or_visitor
# event
# comment            "$Franklin Gutierrez grabbed his left side after a swing and a miss on the third pitch;" "he was helped off the field" kenna001
# Name: 93, dtype: object
#
#
# PIT201106110
# -------------
# event_in_game      29
# inning             3
# home_or_visitor
# event
# comment            "originally scored as double walkn001
# Name: 28, dtype: object
#
#
# SFN201109260
# -------------
# event_in_game      74
# inning             8
# home_or_visitor
# event
# comment            "$Pedro Sandoval hit left-handed due to a sore left shoulder" sandp001
# Name: 73, dtype: object
#
#
# processing game 135,000...
# processing game 136,000...
# processing game 137,000...
# BOS201309020
# -------------
# event_in_game      75
# inning             8
# home_or_visitor
# event
# comment            "$Shane Victorino fouled the third pitch and it struck HP" "umpire Eric Cooper on the left collarbone" victs001
# Name: 74, dtype: object
#
#
# processing game 138,000...
# OAK201309040
# -------------
# event_in_game      119
# inning             9
# home_or_visitor    0
# event
# comment            "$Engel Beltre batted in the sixth spot as if the fifth and" "sixth spots had not changed defensive positions"
# Name: 118, dtype: object
#
#
# processing game 139,000...
# TBA201308160
# -------------
# event_in_game      24
# inning             3
# home_or_visitor
# event
# comment            "originally scored a triple "08-22-2013" lobaj001
# Name: 23, dtype: object
#
#
# CIN201409100
# -------------
# event_in_game      29
# inning             3
# home_or_visitor
# event
# comment            "ej "Cardinals pitcher John Lackey ejected by HP umpire Tom Hallion" penab002
# Name: 28, dtype: object
#
#
# processing game 140,000...
# NYA201406190
# -------------
# event_in_game      74
# inning             6
# home_or_visitor
# event
# comment            "Yankees third baseman Kelly Johnson left the game due to an injured hand" solay001
# Name: 73, dtype: object
#
#
# processing game 141,000...
# processing game 142,000...
# KCA201509030
# -------------
# event_in_game      40
# inning             3
# home_or_visitor
# event
# comment            "Tigers shortstop Jose Iglesias left the game due to an injured hand" romia001
# Name: 39, dtype: object
#
#
# processing game 143,000...
# processing game 144,000...
# processing game 145,000...
# TEX201608310
# -------------
# event_in_game      96
# inning             7
# home_or_visitor
# event
# comment            "ej "Mariners pitcher Arquimedes Caminero ejected by HP umpire Todd Tichenor" vendp001
# Name: 95, dtype: object
#
#
# preparing to save file...
# done

# %%
with open('events.json','w') as f:
    json.dump(allgames, f)#.encode('utf-8')
print('done')
# Out:
# done

# %%
    # replace event types with number codes for fastness
#    thisgameevents_df['event_type'] = numpy.where((thisgameevents_df['event_type'] == 'play'),0,(thisgameevents_df['event_type']))
#    thisgameevents_df['event_type'] = numpy.where((thisgameevents_df['event_type'] == 'sub'),1,(thisgameevents_df['event_type']))
#    thisgameevents_df['event_type'] = numpy.where((thisgameevents_df['event_type'] == 'com'),2,(thisgameevents_df['event_type']))
#    thisgameevents_df['event_type'] = numpy.where((thisgameevents_df['event_type'] == 'badj'),3,(thisgameevents_df['event_type']))
#    thisgameevents_df['event_type'] = numpy.where((thisgameevents_df['event_type'] == 'padj'),4,(thisgameevents_df['event_type']))
#    thisgameevents_df['event_type'] = numpy.where((thisgameevents_df['event_type'] == 'badj'),5,(thisgameevents_df['event_type']))
#    thisgameevents_df['event_type'] = pandas.to_numeric(thisgameevents_df['event_type'])
